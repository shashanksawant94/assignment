# %%
# Task 1
# 1. Install Jupyter notebook and run the first program and share the screenshot of the output.

l = 'python'
l=l.upper()
print(l)
# Out:
# PYTHON

# %% [markdown]
# ![Task1-1.jpg](attachment:Task1-1.jpg)

# %%
# Task 1
# 2. Write a program which will find all such numbers which are divisible by 7 but are not a multiple
#of 5, between 2000 and 3200 (both included). The numbers obtained should be printed in a
#comma-separated sequence on a single line.

for i in range(2000,3201):
    if (i%7 == 0 and i%5 != 0):
        print(i, end = ',')
# Out:
# 2002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,2219,2226,2233,2247,2254,2261,2268,2282,2289,2296,2303,2317,2324,2331,2338,2352,2359,2366,2373,2387,2394,2401,2408,2422,2429,2436,2443,2457,2464,2471,2478,2492,2499,2506,2513,2527,2534,2541,2548,2562,2569,2576,2583,2597,2604,2611,2618,2632,2639,2646,2653,2667,2674,2681,2688,2702,2709,2716,2723,2737,2744,2751,2758,2772,2779,2786,2793,2807,2814,2821,2828,2842,2849,2856,2863,2877,2884,2891,2898,2912,2919,2926,2933,2947,2954,2961,2968,2982,2989,2996,3003,3017,3024,3031,3038,3052,3059,3066,3073,3087,3094,3101,3108,3122,3129,3136,3143,3157,3164,3171,3178,3192,3199,

# %%
# Task 1
# 3. Write a Python program to accept the user's first and last name and then getting them printed in
#the the reverse order with a space between first name and last name.

first_name = input('Enter your first name ')

last_name = input('Enter your last name ')

first_name_len = len(first_name)

last_name_len = len(last_name)

rev_first_name = first_name[first_name_len::-1]

rev_last_name = last_name[last_name_len::-1]

print(rev_first_name+' '+rev_last_name)
# Out:
# Enter your first name shashank
# Enter your last name sawant
# knahsahs tnawas

# %%
# Task 1
# 4. Write a Python program to find the volume of a sphere with diameter 12 cm.
#Formula: V=4/3 * π * r 3

diameter = 12
radius = diameter/2
volume = (4/3)*(22/7)*radius**3
print('Volume of sphere is ',volume,'cc')
# Out:
# Volume of sphere is  905.142857142857 cc

# %%
# Task 2
# 1. Write a program which accepts a sequence of comma-separated numbers from console and
#generate a list.

numbers=input('Enter comma-separated numbers ')
print(numbers.split(','))
# Out:
# Enter comma-separated numbers 11,22,33,44,55
# ['11', '22', '33', '44', '55']

# %%
# Task 2
# 2. Create the below pattern using nested for loop in Python.
for i in range(5):
    for j in range(i+1):
        print('*', end = '')
    print()
for a in range(i):
    for b in range(4-a):
        print('*', end = '')
    print()
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %%
# Task 2
# 3. Write a Python program to reverse a word after accepting the input from the user.
word = input('Input word: ')
rev_word = word[::-1]
print('Output:',rev_word)
# Out:
# Input word: Machine
# Output: enihcaM

# %%
# Task 2
# 4. Write a Python Program to print the given string in the format specified in the sample output.

print('WE, THE PEOPLE OF INDIA,\n\t having solemnly resolved to constitute India into a SOVEREIGN,{}\n\t\t  SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC\n\t\t   and to secure to all its citizens'.format('!').expandtabs(5))
# Out:
# WE, THE PEOPLE OF INDIA,
#       having solemnly resolved to constitute India into a SOVEREIGN,!
#             SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC
#              and to secure to all its citizens

# %% [markdown]
# ![Task2-4.jpg](attachment:Task2-4.jpg)
